# %% [markdown]
# <a href="https://colab.research.google.com/github/deloyar1/deloyarhossainmumin/blob/main/Grocery_store.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
dataset=pd.read_csv('/content/grocery_chain_data.csv')
dataset.head()
# Out:
#    customer_id         store_name transaction_date           aisle  \
# 0         2824  GreenGrocer Plaza       2023-08-26         Produce
# 1         5506   ValuePlus Market       2024-02-13           Dairy
# 2         4657   ValuePlus Market       2023-11-23          Bakery
# 3         2679  SuperSave Central       2025-01-13  Snacks & Candy
# 4         9935  GreenGrocer Plaza       2023-10-13    Canned Goods
#
#    product_name  quantity  unit_price  total_amount  discount_amount  \
# 0         Pasta       2.0        7.46         14.92             0.00
# 1        Cheese       1.0        1.85          1.85             3.41
# 2        Onions       4.0        7.38         29.52             4.04
# 3        Cereal       3.0        5.50         16.50             1.37
# 4  Orange Juice       5.0        8.66         43.30             1.50
#
#    final_amount  loyalty_points
# 0         14.92             377
# 1         -1.56             111
# 2         25.48             301
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1980 entries, 0 to 1979
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       1980 non-null   int64
#  1   store_name        1955 non-null   object
#  2   transaction_date  1980 non-null   object
#  3   aisle             1980 non-null   object
#  4   product_name      1980 non-null   object
#  5   quantity          1980 non-null   float64
#  6   unit_price        1980 non-null   float64
#  7   total_amount      1980 non-null   float64
#  8   discount_amount   1980 non-null   float64
#  9   final_amount      1980 non-null   float64
#  10  loyalty_points    1980 non-null   int64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 170.3+ KB

# %%
dataset['store_name'] = dataset.store_name.fillna(dataset.store_name.mode()[0])

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1980 entries, 0 to 1979
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       1980 non-null   int64
#  1   store_name        1980 non-null   object
#  2   transaction_date  1980 non-null   object
#  3   aisle             1980 non-null   object
#  4   product_name      1980 non-null   object
#  5   quantity          1980 non-null   float64
#  6   unit_price        1980 non-null   float64
#  7   total_amount      1980 non-null   float64
#  8   discount_amount   1980 non-null   float64
#  9   final_amount      1980 non-null   float64
#  10  loyalty_points    1980 non-null   int64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 170.3+ KB

# %%
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()
dataset['store_name'] = lb.fit_transform(dataset.store_name)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1980 entries, 0 to 1979
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       1980 non-null   int64
#  1   store_name        1980 non-null   int64
#  2   transaction_date  1980 non-null   object
#  3   aisle             1980 non-null   object
#  4   product_name      1980 non-null   object
#  5   quantity          1980 non-null   float64
#  6   unit_price        1980 non-null   float64
#  7   total_amount      1980 non-null   float64
#  8   discount_amount   1980 non-null   float64
#  9   final_amount      1980 non-null   float64
#  10  loyalty_points    1980 non-null   int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 170.3+ KB

# %%
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()
dataset['transaction_date'] = lb.fit_transform(dataset.transaction_date)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1980 entries, 0 to 1979
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       1980 non-null   int64
#  1   store_name        1980 non-null   int64
#  2   transaction_date  1980 non-null   int64
#  3   aisle             1980 non-null   object
#  4   product_name      1980 non-null   object
#  5   quantity          1980 non-null   float64
#  6   unit_price        1980 non-null   float64
#  7   total_amount      1980 non-null   float64
#  8   discount_amount   1980 non-null   float64
#  9   final_amount      1980 non-null   float64
#  10  loyalty_points    1980 non-null   int64
# dtypes: float64(5), int64(4), object(2)
# memory usage: 170.3+ KB

# %%
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()
dataset['aisle '] = lb.fit_transform(dataset.aisle )

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1980 entries, 0 to 1979
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       1980 non-null   int64
#  1   store_name        1980 non-null   int64
#  2   transaction_date  1980 non-null   int64
#  3   aisle             1980 non-null   object
#  4   product_name      1980 non-null   object
#  5   quantity          1980 non-null   float64
#  6   unit_price        1980 non-null   float64
#  7   total_amount      1980 non-null   float64
#  8   discount_amount   1980 non-null   float64
#  9   final_amount      1980 non-null   float64
#  10  loyalty_points    1980 non-null   int64
#  11  aisle             1980 non-null   int64
# dtypes: float64(5), int64(5), object(2)
# memory usage: 185.8+ KB

# %%
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()
dataset['aisle'] = lb.fit_transform(dataset.aisle)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1980 entries, 0 to 1979
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       1980 non-null   int64
#  1   store_name        1980 non-null   int64
#  2   transaction_date  1980 non-null   int64
#  3   aisle             1980 non-null   int64
#  4   product_name      1980 non-null   object
#  5   quantity          1980 non-null   float64
#  6   unit_price        1980 non-null   float64
#  7   total_amount      1980 non-null   float64
#  8   discount_amount   1980 non-null   float64
#  9   final_amount      1980 non-null   float64
#  10  loyalty_points    1980 non-null   int64
#  11  aisle             1980 non-null   int64
# dtypes: float64(5), int64(6), object(1)
# memory usage: 185.8+ KB

# %%
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()
dataset['product_name'] = lb.fit_transform(dataset.product_name)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1980 entries, 0 to 1979
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       1980 non-null   int64
#  1   store_name        1980 non-null   int64
#  2   transaction_date  1980 non-null   int64
#  3   aisle             1980 non-null   int64
#  4   product_name      1980 non-null   int64
#  5   quantity          1980 non-null   float64
#  6   unit_price        1980 non-null   float64
#  7   total_amount      1980 non-null   float64
#  8   discount_amount   1980 non-null   float64
#  9   final_amount      1980 non-null   float64
#  10  loyalty_points    1980 non-null   int64
#  11  aisle             1980 non-null   int64
# dtypes: float64(5), int64(7)
# memory usage: 185.8 KB

# %%
dataset.head()
# Out:
#    customer_id  store_name  transaction_date  aisle  product_name  quantity  \
# 0         2824           4                15      9            12       2.0
# 1         5506           8               173      3             5       1.0
# 2         4657           8                98      0            10       4.0
# 3         2679           7               488     10             4       3.0
# 4         9935           4                60      2            11       5.0
#
#    unit_price  total_amount  discount_amount  final_amount  loyalty_points  \
# 0        7.46         14.92             0.00         14.92             377
# 1        1.85          1.85             3.41         -1.56             111
# 2        7.38         29.52             4.04         25.48             301
# 3        5.50         16.50             1.37         15.13             490
# 4        8.66         43.30             1.50         41.80              22
#
#    aisle
# 0       9
# 1       3
# 2       0
# 3      10
# ...

# %%
dataset.describe()
# Out:
#        customer_id   store_name  transaction_date        aisle  product_name  \
# count  1980.000000  1980.000000       1980.000000  1980.000000   1980.000000
# mean   5542.958081     3.946465        342.317172     4.942929      8.598485
# std    2575.771856     2.644350        197.021470     3.184931      5.177194
# min    1006.000000     0.000000          0.000000     0.000000      0.000000
# 25%    3271.500000     2.000000        175.000000     2.000000      4.000000
# 50%    5582.500000     4.000000        339.000000     5.000000      9.000000
# 75%    7791.750000     6.000000        514.000000     8.000000     13.000000
# max    9998.000000     8.000000        688.000000    10.000000     17.000000
#
#           quantity   unit_price  total_amount  discount_amount  final_amount  \
# count  1980.000000  1980.000000   1980.000000      1980.000000   1980.000000
# mean      2.968182    15.488045     45.902576         4.469591     41.432985
# ...

# %%
dataset_1 = pd.read_csv("/content/grocery_chain_data.csv")
data_new = dataset_1.dropna()

# %%
data_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1955 entries, 0 to 1979
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       1955 non-null   int64
#  1   store_name        1955 non-null   object
#  2   transaction_date  1955 non-null   object
#  3   aisle             1955 non-null   object
#  4   product_name      1955 non-null   object
#  5   quantity          1955 non-null   float64
#  6   unit_price        1955 non-null   float64
#  7   total_amount      1955 non-null   float64
#  8   discount_amount   1955 non-null   float64
#  9   final_amount      1955 non-null   float64
#  10  loyalty_points    1955 non-null   int64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 183.3+ KB

# %%
import matplotlib.pyplot as plt
plt.scatter(dataset.loyalty_points, dataset['customer_id'])
plt.title("Scatter plot")
plt.xlabel("loyalty_points ")
plt.ylabel("customer_id ")
plt.show();

# %%
data2 = dataset.drop(columns = ['store_name'])

# %%
data2 = dataset.drop(columns = ['transaction_date'])

# %%
data2 = dataset.drop(columns = ['aisle '])

# %%
data2 = dataset.drop(columns = ['product_name'])

# %%
data2
# Out:
#       customer_id  store_name  transaction_date  aisle  quantity  unit_price  \
# 0            2824           4                15      9       2.0        7.46
# 1            5506           8               173      3       1.0        1.85
# 2            4657           8                98      0       4.0        7.38
# 3            2679           7               488     10       3.0        5.50
# 4            9935           4                60      2       5.0        8.66
# ...           ...         ...               ...    ...       ...         ...
# 1975         1699           1               331      4       3.0        9.79
# 1976         1829           0               118      8       4.0       22.96
# 1977         8096           5               600      3       3.0       16.44
# 1978         7471           6               355      4       5.0       15.88
# 1979         1483           2               274      2       2.0       24.94
#
# ...

# %%
x = data2.drop(columns = ['aisle'])
y = data2['aisle']

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(
    x,y, random_state=42, test_size= 0.2
)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(xtrain,ytrain)
lr.score(xtest,ytest)
# Out:
# 1.0

# %%
from sklearn.metrics import mean_squared_error as mse
predicted = lr.predict(xtest)
error = mse(ytest, predicted) ** .5
print(error)
# Out:
# 1.2865636397614001e-14

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression

models = [RandomForestRegressor(), DecisionTreeRegressor(), LinearRegression()]

errors = {}

for model in models:
    model.fit(xtrain,ytrain)
    name = type(model).__name__
    score = model.score(xtest,ytest)*100
    errors[name] = score

# %%
errors
# Out:
# {'RandomForestRegressor': 100.0,
#  'DecisionTreeRegressor': 100.0,
#  'LinearRegression': 100.0}

# %%
import matplotlib.pyplot as plt

plt.bar(errors.keys(),errors.values())
# Out:
# <BarContainer object of 3 artists>

# %%
import matplotlib.pyplot as plt

# Sample data for demonstration (replace with your actual 'errors' dictionary)

# Define a cute pastel color palette
cute_colors = ['#FFB6B9', '#FFDAC1', '#E2F0CB', '#B5EAD7', '#C7CEEA']

# Create the bar chart
plt.figure(figsize=(8, 6))
bars = plt.bar(errors.keys(), errors.values(), color=cute_colors[:len(errors)])

# Add rounded edges to bars
for bar in bars:
    bar.set_linewidth(0)
    bar.set_edgecolor('none')
    bar.set_zorder(3)

# Add labels and title with cute fonts
plt.title('🐾 Chart 🐾', fontsize=16, fontweight='bold', color='#A974BF')
plt.xlabel('Models', fontsize=12, color='#6C5B7B')
plt.ylabel('R values', fontsize=12, color='#6C5B7B')

# Set background color
plt.gca().set_facecolor('#FFF0F5')  # Light lavender pink
plt.grid(axis='y', linestyle='--', alpha=0.4)

# Remove top and right border
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-120495182.py:31: UserWarning: Glyph 128062 (\N{PAW PRINTS}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128062 (\N{PAW PRINTS}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
